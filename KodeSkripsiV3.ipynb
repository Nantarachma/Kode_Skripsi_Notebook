# %% [markdown]
# # Instalasi & Import

# %%
# Cell 1: Install & Import Library
# XGBoost biasanya sudah ada di Kaggle, tapi kita pastikan versinya update
# !pip install xgboost optuna category_encoders

import os
import time
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
import optuna

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score, precision_score, recall_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.utils.class_weight import compute_sample_weight
from optuna.samplers import TPESampler, NSGAIISampler, RandomSampler
from optuna.pruners import SuccessiveHalvingPruner, MedianPruner

# Konfigurasi
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
sns.set_style("whitegrid")

print("✅ Setup Selesai. Menggunakan XGBoost versi:", xgb.__version__)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# /usr/local/lib/python3.12/dist-packages/sqlalchemy/orm/query.py:195: SyntaxWarning: "is not" with 'tuple' literal. Did you mean "!="?
#   if entities is not ():
# ✅ Setup Selesai. Menggunakan XGBoost versi: 3.1.0

# %% [markdown]
# # Load Dataset (Otomatis)

# %%
# Cell 2: Load Data dari Kaggle Input
print("📂 Mencari file dataset di /kaggle/input/ ...")

train_path = None
test_path = None

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        full_path = os.path.join(dirname, filename)
        if "training" in filename.lower() and "csv" in filename:
            train_path = full_path
        elif "testing" in filename.lower() and "csv" in filename:
            test_path = full_path

if train_path and test_path:
    print(f"✅ Training Data: {train_path}")
    print(f"✅ Testing Data: {test_path}")
    
    df_train = pd.read_csv(train_path)
    df_test = pd.read_csv(test_path)
    
    print(f"Shape Train: {df_train.shape}")
    print(f"Shape Test:  {df_test.shape}")
else:
    raise FileNotFoundError("❌ File dataset tidak ditemukan! Pastikan sudah Add Input.")
# Out:
# 📂 Mencari file dataset di /kaggle/input/ ...
# ✅ Training Data: /kaggle/input/unsw-nb15/UNSW_NB15_training-set.csv
# ✅ Testing Data: /kaggle/input/unsw-nb15/UNSW_NB15_testing-set.csv
# Shape Train: (175341, 45)
# Shape Test:  (82332, 45)

# %% [markdown]
# # Preprocessing & Class Weights

# %%
# Cell 3: Preprocessing & Perhitungan Class Weights
# 1. Drop Kolom Sampah
drop_cols = ['id'] 
df_train = df_train.drop(columns=drop_cols, errors='ignore')
df_test = df_test.drop(columns=drop_cols, errors='ignore')

# 2. Pisahkan Fitur & Target
X_train = df_train.drop(columns=['attack_cat', 'label'])
y_train_raw = df_train['attack_cat']

X_test = df_test.drop(columns=['attack_cat', 'label'])
y_test_raw = df_test['attack_cat']

# 3. Encoding Fitur Kategorikal (Label Encoding untuk XGBoost)
# XGBoost bisa handle kategori, tapi lebih aman di-encode angka
cat_cols = X_train.select_dtypes(include=['object']).columns

for col in cat_cols:
    le = LabelEncoder()
    # Fit gabungan agar tidak ada unknown label
    full_data = pd.concat([X_train[col], X_test[col]], axis=0).astype(str)
    le.fit(full_data)
    X_train[col] = le.transform(X_train[col].astype(str))
    X_test[col] = le.transform(X_test[col].astype(str))

# 4. Encoding Target (Multiclass Wajib 0,1,2...)
le_target = LabelEncoder()
y_train = le_target.fit_transform(y_train_raw)
y_test = le_target.transform(y_test_raw)

# 5. Scaling (Disarankan untuk XGBoost agar konvergensi stabil)
scaler = StandardScaler()
X_train_enc = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_enc = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# 6. HITUNG CLASS WEIGHTS (Pengganti SMOTE)
# Kita hitung bobot tiap sampel. Sampel kelas minoritas dapat bobot besar.
sample_weights_train = compute_sample_weight(
    class_weight='balanced',
    y=y_train
)

print("✅ Preprocessing Selesai.")
print(f"Classes: {le_target.classes_}")
print(f"Contoh Sample Weights (5 data awal): {sample_weights_train[:5]}")
# Out:
# ✅ Preprocessing Selesai.
# Classes: ['Analysis' 'Backdoor' 'DoS' 'Exploits' 'Fuzzers' 'Generic' 'Normal'
#  'Reconnaissance' 'Shellcode' 'Worms']
# Contoh Sample Weights (5 data awal): [0.31310893 0.31310893 0.31310893 0.31310893 0.31310893]

# %% [markdown]
# # Definisi Objective Function (Generic)

# %%
# Cell 4: Definisi Objective Function XGBoost (FIXED FOR XGBOOST 2.0)
from xgboost.callback import TrainingCallback
import xgboost as xgb

# Custom Pruning Callback
class OptunaPruningCallback(TrainingCallback):
    def __init__(self, trial, metric_name):
        self.trial = trial
        self.metric_name = metric_name
        
    def after_iteration(self, model, epoch, evals_log):
        if not evals_log:
            return False
        current_score = evals_log['validation_0'][self.metric_name][-1]
        self.trial.report(current_score, epoch)
        if self.trial.should_prune():
            raise optuna.exceptions.TrialPruned()
        return False

def objective_xgboost(trial):
    # 1. Hyperparameter Space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 3000),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0, log=True),
        
        # --- PERBAIKAN UTAMA DI SINI (XGBoost 2.0+) ---
        'objective': 'multi:softmax',
        'num_class': len(le_target.classes_),
        'tree_method': 'hist',  # Ganti 'gpu_hist' menjadi 'hist'
        'device': 'cuda',       # Tambahkan ini untuk mengaktifkan GPU
        'eval_metric': 'mlogloss',
        'verbosity': 0
    }

    # 2. Setup Pruning
    pruning_callback = OptunaPruningCallback(trial, "mlogloss")

    # 3. Model Training
    model = xgb.XGBClassifier(
        **param, 
        random_state=42, 
        callbacks=[pruning_callback]
    )
    
    model.fit(
        X_train_enc, y_train,
        sample_weight=sample_weights_train, 
        eval_set=[(X_test_enc, y_test)],
        verbose=False
    )

    # 4. Evaluasi
    preds = model.predict(X_test_enc)
    f1 = f1_score(y_test, preds, average='macro')
    
    return f1
print("✅ Define Objective Function Selesai.")
# Out:
# ✅ Define Objective Function Selesai.

# %% [markdown]
# # Strategi 1 - Optuna TPE (Tree-structured Parzen Estimator)

# %%
# Cell 5: Optimasi TPE
print("🚀 Memulai Optimasi TPE...")
start_time = time.time()

# Sampler TPE, Pruner Median (Standar)
study_tpe = optuna.create_study(
    direction='maximize',
    sampler=TPESampler(seed=42),
    pruner=MedianPruner(n_startup_trials=5, n_warmup_steps=5)
)

study_tpe.optimize(objective_xgboost, n_trials=30)
time_tpe = time.time() - start_time

print(f"✅ TPE Selesai dalam {time_tpe:.2f} detik.")
print(f"Best F1 TPE: {study_tpe.best_value}")
# Out:
# [I 2025-12-29 14:20:18,033] A new study created in memory with name: no-name-f98d9e09-3268-4273-9d8c-091a6cd1880c
# 🚀 Memulai Optimasi TPE...
# [I 2025-12-29 14:20:57,350] Trial 0 finished with value: 0.5167651539650223 and parameters: {'n_estimators': 1436, 'max_depth': 12, 'learning_rate': 0.1205712628744377, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'min_child_weight': 1, 'reg_alpha': 0.08499808989182997, 'reg_lambda': 0.0006440507553993703}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:21:23,362] Trial 1 finished with value: 0.5119503845065664 and parameters: {'n_estimators': 2270, 'max_depth': 3, 'learning_rate': 0.2708160864249968, 'subsample': 0.9162213204002109, 'colsample_bytree': 0.6061695553391381, 'gamma': 0.9091248360355031, 'min_child_weight': 2, 'reg_alpha': 2.716051144654844e-06, 'reg_lambda': 0.00015777981883364995}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:21:49,078] Trial 2 finished with value: 0.5074041522721873 and parameters: {'n_estimators': 1580, 'max_depth': 5, 'learning_rate': 0.08012737503998542, 'subsample': 0.569746930326021, 'colsample_bytree': 0.6460723242676091, 'gamma': 1.8318092164684585, 'min_child_weight': 5, 'reg_alpha': 0.019116469627784252, 'reg_lambda': 3.9572205641009174e-07}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:22:50,636] Trial 3 finished with value: 0.5130352592956026 and parameters: {'n_estimators': 1786, 'max_depth': 8, 'learning_rate': 0.011711509955524094, 'subsample': 0.8037724259507192, 'colsample_bytree': 0.5852620618436457, 'gamma': 0.3252579649263976, 'min_child_weight': 10, 'reg_alpha': 0.530953226900921, 'reg_lambda': 0.02932100047183291}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:23:06,767] Trial 4 finished with value: 0.4989088564142407 and parameters: {'n_estimators': 1261, 'max_depth': 3, 'learning_rate': 0.1024932221692416, 'subsample': 0.7200762468698007, 'colsample_bytree': 0.5610191174223894, 'gamma': 2.475884550556351, 'min_child_weight': 1, 'reg_alpha': 0.1881755597772026, 'reg_lambda': 1.1755466083160747e-06}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:23:33,690] Trial 5 finished with value: 0.4938982047605994 and parameters: {'n_estimators': 2156, 'max_depth': 6, 'learning_rate': 0.05864129169696527, 'subsample': 0.7733551396716398, 'colsample_bytree': 0.5924272277627636, 'gamma': 4.847923138822793, 'min_child_weight': 8, 'reg_alpha': 0.32808889626606236, 'reg_lambda': 0.14408501080722544}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:24:42,742] Trial 6 finished with value: 0.5121997994756844 and parameters: {'n_estimators': 1995, 'max_depth': 12, 'learning_rate': 0.01351182947645082, 'subsample': 0.5979914312095727, 'colsample_bytree': 0.522613644455269, 'gamma': 1.6266516538163218, 'min_child_weight': 4, 'reg_alpha': 1.481809088646707e-06, 'reg_lambda': 0.04264813784432918}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:25:13,173] Trial 7 finished with value: 0.5233062507090469 and parameters: {'n_estimators': 1392, 'max_depth': 5, 'learning_rate': 0.06333268775321842, 'subsample': 0.5704621124873813, 'colsample_bytree': 0.9010984903770198, 'gamma': 0.3727532183988541, 'min_child_weight': 10, 'reg_alpha': 0.015064619068942013, 'reg_lambda': 3.8879928024075543e-07}. Best is trial 7 with value: 0.5233062507090469.
# [I 2025-12-29 14:25:32,972] Trial 8 finished with value: 0.5250779765638034 and parameters: {'n_estimators': 513, 'max_depth': 11, 'learning_rate': 0.11069143219393454, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'min_child_weight': 4, 'reg_alpha': 8.451863533931625e-08, 'reg_lambda': 0.08032068562667222}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:26:12,447] Trial 9 finished with value: 0.4960946815633471 and parameters: {'n_estimators': 2058, 'max_depth': 6, 'learning_rate': 0.012413189635294229, 'subsample': 0.6554911608578311, 'colsample_bytree': 0.6625916610133735, 'gamma': 3.64803089169032, 'min_child_weight': 7, 'reg_alpha': 0.12522814303053625, 'reg_lambda': 5.994036749692399e-05}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:26:25,655] Trial 10 finished with value: 0.50381268258737 and parameters: {'n_estimators': 551, 'max_depth': 10, 'learning_rate': 0.028477486830279865, 'subsample': 0.968324376628699, 'colsample_bytree': 0.9896117410993797, 'gamma': 3.451235367845724, 'min_child_weight': 3, 'reg_alpha': 1.22719924263834e-08, 'reg_lambda': 0.5682043863802073}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:28:13,820] Trial 11 finished with value: 0.5134524290004859 and parameters: {'n_estimators': 2919, 'max_depth': 9, 'learning_rate': 0.19265640527744932, 'subsample': 0.5121573992610217, 'colsample_bytree': 0.8936221864929604, 'gamma': 0.10341117636531916, 'min_child_weight': 10, 'reg_alpha': 0.0007202349503619226, 'reg_lambda': 1.578453372227308e-08}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:28:30,137] Trial 12 finished with value: 0.5076493620939189 and parameters: {'n_estimators': 529, 'max_depth': 10, 'learning_rate': 0.03563187904360772, 'subsample': 0.869990841315495, 'colsample_bytree': 0.8280382521790727, 'gamma': 1.372424866412404, 'min_child_weight': 7, 'reg_alpha': 0.0014208422567909052, 'reg_lambda': 4.443084116943277e-06}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:28:51,172] Trial 13 finished with value: 0.5140231734263554 and parameters: {'n_estimators': 938, 'max_depth': 5, 'learning_rate': 0.03891469423179501, 'subsample': 0.7039294159774772, 'colsample_bytree': 0.8063670284006881, 'gamma': 0.12774747405271514, 'min_child_weight': 5, 'reg_alpha': 9.254507559199248e-06, 'reg_lambda': 0.0030481537207848316}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:29:05,690] Trial 14 finished with value: 0.5028137294049493 and parameters: {'n_estimators': 1033, 'max_depth': 7, 'learning_rate': 0.150600120767256, 'subsample': 0.8690491710631161, 'colsample_bytree': 0.9462653375960717, 'gamma': 2.337404800162277, 'min_child_weight': 8, 'reg_alpha': 9.115307210703232e-08, 'reg_lambda': 2.626329270646006e-08}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:30:38,108] Trial 15 finished with value: 0.5171675427792958 and parameters: {'n_estimators': 2644, 'max_depth': 11, 'learning_rate': 0.06965974284898135, 'subsample': 0.5054945946218855, 'colsample_bytree': 0.7362841638557037, 'gamma': 0.9016014536963488, 'min_child_weight': 3, 'reg_alpha': 7.555278723981503e-05, 'reg_lambda': 1.15772789034682e-05}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:30:53,035] Trial 16 finished with value: 0.486525185350626 and parameters: {'n_estimators': 907, 'max_depth': 4, 'learning_rate': 0.023750559065887168, 'subsample': 0.9898232498406144, 'colsample_bytree': 0.8818736974574264, 'gamma': 3.754986180062629, 'min_child_weight': 6, 'reg_alpha': 0.004545229623549673, 'reg_lambda': 2.441932910378409e-07}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:31:28,386] Trial 17 finished with value: 0.5176486372946599 and parameters: {'n_estimators': 1190, 'max_depth': 8, 'learning_rate': 0.047278746663206896, 'subsample': 0.6509953611804162, 'colsample_bytree': 0.7537458820696782, 'gamma': 0.7237162723079159, 'min_child_weight': 9, 'reg_alpha': 8.629954786816072e-05, 'reg_lambda': 0.0056241858053197626}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:31:38,565] Trial 18 finished with value: 0.5023823709406899 and parameters: {'n_estimators': 671, 'max_depth': 7, 'learning_rate': 0.0956117222789428, 'subsample': 0.8712879172263445, 'colsample_bytree': 0.9095336881172503, 'gamma': 2.9575883549786277, 'min_child_weight': 4, 'reg_alpha': 2.7306960399413254e-07, 'reg_lambda': 2.716426795966996e-05}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:32:31,385] Trial 19 finished with value: 0.5113297269858053 and parameters: {'n_estimators': 2464, 'max_depth': 10, 'learning_rate': 0.199126618675408, 'subsample': 0.5958905332534877, 'colsample_bytree': 0.9870770823244983, 'gamma': 2.032041783642748, 'min_child_weight': 6, 'reg_alpha': 2.042991747871708e-05, 'reg_lambda': 0.0012658602549654547}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:32:56,605] Trial 20 finished with value: 0.5140933882802571 and parameters: {'n_estimators': 1721, 'max_depth': 5, 'learning_rate': 0.14017675316339803, 'subsample': 0.8350749086486079, 'colsample_bytree': 0.8314063332863683, 'gamma': 1.2003924643686852, 'min_child_weight': 4, 'reg_alpha': 1.2387044364130502e-08, 'reg_lambda': 0.8927755344760302}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:33:33,206] Trial 21 finished with value: 0.5170011676240704 and parameters: {'n_estimators': 1246, 'max_depth': 8, 'learning_rate': 0.047954446785971, 'subsample': 0.6617589560673869, 'colsample_bytree': 0.7453653736254292, 'gamma': 0.7184715880731084, 'min_child_weight': 9, 'reg_alpha': 0.00017729641558918716, 'reg_lambda': 0.009879589702623271}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:34:19,382] Trial 22 finished with value: 0.5202159768698479 and parameters: {'n_estimators': 1295, 'max_depth': 9, 'learning_rate': 0.05810544567918913, 'subsample': 0.6554729527204557, 'colsample_bytree': 0.7970731939575223, 'gamma': 0.4392801666813403, 'min_child_weight': 9, 'reg_alpha': 0.01128912676154791, 'reg_lambda': 0.00025298614928459176}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:34:47,862] Trial 23 finished with value: 0.5183950549673917 and parameters: {'n_estimators': 780, 'max_depth': 9, 'learning_rate': 0.07248555558835504, 'subsample': 0.7301413147085984, 'colsample_bytree': 0.8625840057728943, 'gamma': 0.4060992659717185, 'min_child_weight': 9, 'reg_alpha': 0.011736702630192782, 'reg_lambda': 0.00025268572285790027}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:35:40,513] Trial 24 finished with value: 0.5147576407791232 and parameters: {'n_estimators': 1455, 'max_depth': 11, 'learning_rate': 0.019828800819603074, 'subsample': 0.555793133217648, 'colsample_bytree': 0.7830490167548361, 'gamma': 1.277057216665955, 'min_child_weight': 10, 'reg_alpha': 0.0008591631421001114, 'reg_lambda': 7.956431682853554e-06}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:36:54,364] Trial 25 finished with value: 0.523086794803809 and parameters: {'n_estimators': 1813, 'max_depth': 9, 'learning_rate': 0.05909884341108218, 'subsample': 0.6199729602179717, 'colsample_bytree': 0.924846322558455, 'gamma': 0.0024696565011918525, 'min_child_weight': 8, 'reg_alpha': 0.024647411757128406, 'reg_lambda': 9.908461743864089e-08}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:37:25,094] Trial 26 finished with value: 0.49769010724945806 and parameters: {'n_estimators': 1864, 'max_depth': 11, 'learning_rate': 0.09365098199228716, 'subsample': 0.5644029127862145, 'colsample_bytree': 0.9384889530016627, 'gamma': 4.954888318934101, 'min_child_weight': 7, 'reg_alpha': 0.04016172450645102, 'reg_lambda': 8.865794346341226e-08}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:38:05,257] Trial 27 finished with value: 0.5179098423529671 and parameters: {'n_estimators': 1584, 'max_depth': 6, 'learning_rate': 0.032504771463468266, 'subsample': 0.613376312241825, 'colsample_bytree': 0.944403315221004, 'gamma': 0.43568632941942914, 'min_child_weight': 8, 'reg_alpha': 0.8334871777525105, 'reg_lambda': 1.8481910639270992e-06}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:39:40,814] Trial 28 finished with value: 0.5255424954261267 and parameters: {'n_estimators': 2297, 'max_depth': 10, 'learning_rate': 0.04732781909204586, 'subsample': 0.9358157196175474, 'colsample_bytree': 0.8565122554129693, 'gamma': 0.053421135819688825, 'min_child_weight': 6, 'reg_alpha': 0.004182536493375578, 'reg_lambda': 9.071758645029453e-08}. Best is trial 28 with value: 0.5255424954261267.
# [I 2025-12-29 14:40:20,356] Trial 29 finished with value: 0.5133574314707492 and parameters: {'n_estimators': 2381, 'max_depth': 12, 'learning_rate': 0.11846798815149824, 'subsample': 0.9250466523063767, 'colsample_bytree': 0.8585471898100924, 'gamma': 1.1240428166576353, 'min_child_weight': 3, 'reg_alpha': 0.0003576929737070559, 'reg_lambda': 7.20858942089291e-07}. Best is trial 28 with value: 0.5255424954261267.
# ✅ TPE Selesai dalam 1202.33 detik.
# Best F1 TPE: 0.5255424954261267

# %% [markdown]
# # Strategi 2 - Optuna ASHA (Asynchronous Successive Halving)

# %%
# Cell 6: Optimasi ASHA
print("🚀 Memulai Optimasi ASHA...")
start_time = time.time()

# Di Optuna, ASHA diimplementasikan lewat SuccessiveHalvingPruner
# Sampler biasanya RandomSampler agar eksplorasi luas, lalu dipangkas ASHA
study_asha = optuna.create_study(
    direction='maximize',
    sampler=RandomSampler(seed=42), 
    pruner=SuccessiveHalvingPruner(min_resource=100, reduction_factor=3)
)

study_asha.optimize(objective_xgboost, n_trials=30)
time_asha = time.time() - start_time

print(f"✅ ASHA Selesai dalam {time_asha:.2f} detik.")
print(f"Best F1 ASHA: {study_asha.best_value}")
# Out:
# [I 2025-12-29 14:41:00,098] A new study created in memory with name: no-name-7f45e1b5-9cdc-4b68-a862-5e9600f9608e
# 🚀 Memulai Optimasi ASHA...
# [I 2025-12-29 14:41:38,484] Trial 0 finished with value: 0.5167651539650223 and parameters: {'n_estimators': 1436, 'max_depth': 12, 'learning_rate': 0.1205712628744377, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'min_child_weight': 1, 'reg_alpha': 0.08499808989182997, 'reg_lambda': 0.0006440507553993703}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:41:42,955] Trial 1 pruned.
# [I 2025-12-29 14:41:49,217] Trial 2 pruned.
# [I 2025-12-29 14:42:20,148] Trial 3 pruned.
# [I 2025-12-29 14:42:22,097] Trial 4 pruned.
# [I 2025-12-29 14:42:24,946] Trial 5 pruned.
# [I 2025-12-29 14:42:41,674] Trial 6 pruned.
# [I 2025-12-29 14:42:44,307] Trial 7 pruned.
# [I 2025-12-29 14:42:49,911] Trial 8 pruned.
# [I 2025-12-29 14:43:10,243] Trial 9 pruned.
# [I 2025-12-29 14:43:13,668] Trial 10 pruned.
# [I 2025-12-29 14:43:18,282] Trial 11 pruned.
# [I 2025-12-29 14:43:31,223] Trial 12 pruned.
# [I 2025-12-29 14:43:36,238] Trial 13 pruned.
# [I 2025-12-29 14:43:53,428] Trial 14 pruned.
# [I 2025-12-29 14:43:56,404] Trial 15 pruned.
# [I 2025-12-29 14:43:58,366] Trial 16 pruned.
# [I 2025-12-29 14:44:13,823] Trial 17 pruned.
# [I 2025-12-29 14:44:25,263] Trial 18 pruned.
# [I 2025-12-29 14:44:29,183] Trial 19 pruned.
# [I 2025-12-29 14:44:31,192] Trial 20 pruned.
# [I 2025-12-29 14:44:33,121] Trial 21 pruned.
# [I 2025-12-29 14:44:36,658] Trial 22 pruned.
# [I 2025-12-29 14:44:50,236] Trial 23 pruned.
# [I 2025-12-29 14:44:53,940] Trial 24 pruned.
# [I 2025-12-29 14:44:58,787] Trial 25 pruned.
# [I 2025-12-29 14:45:03,860] Trial 26 pruned.
# [I 2025-12-29 14:45:05,750] Trial 27 pruned.
# [I 2025-12-29 14:45:13,579] Trial 28 pruned.
# [I 2025-12-29 14:45:15,887] Trial 29 pruned.
# ✅ ASHA Selesai dalam 255.79 detik.
# Best F1 ASHA: 0.5167651539650223

# %% [markdown]
# # Strategi 3 - Optuna NSGA-II (Genetic Algorithm)

# %%
# Cell 7: Optimasi NSGA-II
print("🚀 Memulai Optimasi NSGA-II...")
start_time = time.time()

# Sampler NSGA-II
study_nsga = optuna.create_study(
    direction='maximize',
    sampler=NSGAIISampler(seed=42),
    pruner=MedianPruner(n_startup_trials=5, n_warmup_steps=5) # NSGA-II juga bisa pakai pruner
)

study_nsga.optimize(objective_xgboost, n_trials=30)
time_nsga = time.time() - start_time

print(f"✅ NSGA-II Selesai dalam {time_nsga:.2f} detik.")
print(f"Best F1 NSGA-II: {study_nsga.best_value}")
# Out:
# [I 2025-12-29 14:45:32,582] A new study created in memory with name: no-name-e09cafd4-d83b-4163-ab5a-16211af91761
# 🚀 Memulai Optimasi NSGA-II...
# [I 2025-12-29 14:46:11,483] Trial 0 finished with value: 0.5167651539650223 and parameters: {'n_estimators': 1436, 'max_depth': 12, 'learning_rate': 0.1205712628744377, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'min_child_weight': 1, 'reg_alpha': 0.08499808989182997, 'reg_lambda': 0.0006440507553993703}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:46:37,226] Trial 1 finished with value: 0.5119503845065664 and parameters: {'n_estimators': 2270, 'max_depth': 3, 'learning_rate': 0.2708160864249968, 'subsample': 0.9162213204002109, 'colsample_bytree': 0.6061695553391381, 'gamma': 0.9091248360355031, 'min_child_weight': 2, 'reg_alpha': 2.716051144654844e-06, 'reg_lambda': 0.00015777981883364995}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:47:02,650] Trial 2 finished with value: 0.5074041522721873 and parameters: {'n_estimators': 1580, 'max_depth': 5, 'learning_rate': 0.08012737503998542, 'subsample': 0.569746930326021, 'colsample_bytree': 0.6460723242676091, 'gamma': 1.8318092164684585, 'min_child_weight': 5, 'reg_alpha': 0.019116469627784252, 'reg_lambda': 3.9572205641009174e-07}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:48:03,490] Trial 3 finished with value: 0.5130352592956026 and parameters: {'n_estimators': 1786, 'max_depth': 8, 'learning_rate': 0.011711509955524094, 'subsample': 0.8037724259507192, 'colsample_bytree': 0.5852620618436457, 'gamma': 0.3252579649263976, 'min_child_weight': 10, 'reg_alpha': 0.530953226900921, 'reg_lambda': 0.02932100047183291}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:48:19,390] Trial 4 finished with value: 0.4989088564142407 and parameters: {'n_estimators': 1261, 'max_depth': 3, 'learning_rate': 0.1024932221692416, 'subsample': 0.7200762468698007, 'colsample_bytree': 0.5610191174223894, 'gamma': 2.475884550556351, 'min_child_weight': 1, 'reg_alpha': 0.1881755597772026, 'reg_lambda': 1.1755466083160747e-06}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:48:45,639] Trial 5 finished with value: 0.4938982047605994 and parameters: {'n_estimators': 2156, 'max_depth': 6, 'learning_rate': 0.05864129169696527, 'subsample': 0.7733551396716398, 'colsample_bytree': 0.5924272277627636, 'gamma': 4.847923138822793, 'min_child_weight': 8, 'reg_alpha': 0.32808889626606236, 'reg_lambda': 0.14408501080722544}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:49:53,895] Trial 6 finished with value: 0.5121997994756844 and parameters: {'n_estimators': 1995, 'max_depth': 12, 'learning_rate': 0.01351182947645082, 'subsample': 0.5979914312095727, 'colsample_bytree': 0.522613644455269, 'gamma': 1.6266516538163218, 'min_child_weight': 4, 'reg_alpha': 1.481809088646707e-06, 'reg_lambda': 0.04264813784432918}. Best is trial 0 with value: 0.5167651539650223.
# [I 2025-12-29 14:50:23,921] Trial 7 finished with value: 0.5233062507090469 and parameters: {'n_estimators': 1392, 'max_depth': 5, 'learning_rate': 0.06333268775321842, 'subsample': 0.5704621124873813, 'colsample_bytree': 0.9010984903770198, 'gamma': 0.3727532183988541, 'min_child_weight': 10, 'reg_alpha': 0.015064619068942013, 'reg_lambda': 3.8879928024075543e-07}. Best is trial 7 with value: 0.5233062507090469.
# [I 2025-12-29 14:50:43,566] Trial 8 finished with value: 0.5250779765638034 and parameters: {'n_estimators': 513, 'max_depth': 11, 'learning_rate': 0.11069143219393454, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'gamma': 0.3702232586704518, 'min_child_weight': 4, 'reg_alpha': 8.451863533931625e-08, 'reg_lambda': 0.08032068562667222}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:51:22,528] Trial 9 finished with value: 0.4960946815633471 and parameters: {'n_estimators': 2058, 'max_depth': 6, 'learning_rate': 0.012413189635294229, 'subsample': 0.6554911608578311, 'colsample_bytree': 0.6625916610133735, 'gamma': 3.64803089169032, 'min_child_weight': 7, 'reg_alpha': 0.12522814303053625, 'reg_lambda': 5.994036749692399e-05}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:51:36,920] Trial 10 finished with value: 0.502401964539265 and parameters: {'n_estimators': 799, 'max_depth': 10, 'learning_rate': 0.13297554090738672, 'subsample': 0.7806385987847482, 'colsample_bytree': 0.8854835899772805, 'gamma': 2.4689779818219537, 'min_child_weight': 6, 'reg_alpha': 2.632256136809142e-05, 'reg_lambda': 1.5971768764426203e-08}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:51:47,182] Trial 11 finished with value: 0.4796514022310344 and parameters: {'n_estimators': 769, 'max_depth': 3, 'learning_rate': 0.08710745900492396, 'subsample': 0.6571779905381634, 'colsample_bytree': 0.7542853455823514, 'gamma': 4.537832369630465, 'min_child_weight': 3, 'reg_alpha': 1.918948786414487e-05, 'reg_lambda': 0.011076667222301087}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:52:03,102] Trial 12 finished with value: 0.47358767788696854 and parameters: {'n_estimators': 1072, 'max_depth': 3, 'learning_rate': 0.02679156169946617, 'subsample': 0.5806106436270022, 'colsample_bytree': 0.9648488261712865, 'gamma': 4.040601897822085, 'min_child_weight': 7, 'reg_alpha': 0.0936881625557718, 'reg_lambda': 0.026876741555610546}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:52:21,836] Trial 13 finished with value: 0.5122852327257625 and parameters: {'n_estimators': 966, 'max_depth': 11, 'learning_rate': 0.06261435181296006, 'subsample': 0.9037200775820313, 'colsample_bytree': 0.9480456499617467, 'gamma': 1.5900173748593194, 'min_child_weight': 2, 'reg_alpha': 6.660108438734075e-07, 'reg_lambda': 2.6113333123958975e-05}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:53:49,108] Trial 14 finished with value: 0.5160118441003335 and parameters: {'n_estimators': 2545, 'max_depth': 11, 'learning_rate': 0.010239273411172712, 'subsample': 0.7553736512887829, 'colsample_bytree': 0.7087055015743895, 'gamma': 1.1105390523536514, 'min_child_weight': 2, 'reg_alpha': 5.022516489125307e-06, 'reg_lambda': 0.3493635816569516}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:54:07,521] Trial 15 finished with value: 0.49287245711607197 and parameters: {'n_estimators': 1308, 'max_depth': 8, 'learning_rate': 0.10925573591447926, 'subsample': 0.681814801189647, 'colsample_bytree': 0.9858910413604803, 'gamma': 4.812236474710556, 'min_child_weight': 3, 'reg_alpha': 9.505786310154948e-05, 'reg_lambda': 2.5528569432507475e-06}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:54:24,794] Trial 16 finished with value: 0.49780398984253127 and parameters: {'n_estimators': 1212, 'max_depth': 3, 'learning_rate': 0.07950609693143304, 'subsample': 0.7513395116144308, 'colsample_bytree': 0.5257393756249946, 'gamma': 1.3932323211830573, 'min_child_weight': 10, 'reg_alpha': 8.25078224477252e-07, 'reg_lambda': 1.4426433452224793e-07}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:55:13,629] Trial 17 finished with value: 0.5108604175180578 and parameters: {'n_estimators': 1724, 'max_depth': 12, 'learning_rate': 0.022779541913782567, 'subsample': 0.8360677737029393, 'colsample_bytree': 0.8808098076643588, 'gamma': 1.1881877199619983, 'min_child_weight': 8, 'reg_alpha': 8.755179646617154e-06, 'reg_lambda': 0.001144054318382189}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:56:05,281] Trial 18 finished with value: 0.5133559178802783 and parameters: {'n_estimators': 2084, 'max_depth': 8, 'learning_rate': 0.013594678406051506, 'subsample': 0.917651247794619, 'colsample_bytree': 0.6603900324858679, 'gamma': 0.9325925519992712, 'min_child_weight': 1, 'reg_alpha': 0.0005335112055356552, 'reg_lambda': 0.002633388257869831}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:56:19,749] Trial 19 finished with value: 0.49914090556412793 and parameters: {'n_estimators': 541, 'max_depth': 8, 'learning_rate': 0.02160537077027906, 'subsample': 0.822586395204725, 'colsample_bytree': 0.5871832145024958, 'gamma': 3.45468869051233, 'min_child_weight': 4, 'reg_alpha': 0.31177401074836186, 'reg_lambda': 1.2594112057549154e-07}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:56:33,956] Trial 20 finished with value: 0.4910467150951369 and parameters: {'n_estimators': 1353, 'max_depth': 4, 'learning_rate': 0.2322119672134763, 'subsample': 0.9386696766904905, 'colsample_bytree': 0.6289708138575778, 'gamma': 3.299920230170895, 'min_child_weight': 9, 'reg_alpha': 0.00027644356998183205, 'reg_lambda': 0.00017266512478892476}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:56:46,639] Trial 21 finished with value: 0.5015933384525745 and parameters: {'n_estimators': 1104, 'max_depth': 3, 'learning_rate': 0.21149322814164553, 'subsample': 0.9502090285816652, 'colsample_bytree': 0.816550728636634, 'gamma': 1.6951489552435035, 'min_child_weight': 4, 'reg_alpha': 0.006421632248858025, 'reg_lambda': 0.15027338858202638}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:57:29,472] Trial 22 finished with value: 0.4990051608836721 and parameters: {'n_estimators': 2718, 'max_depth': 10, 'learning_rate': 0.08878888265538125, 'subsample': 0.5420699824975244, 'colsample_bytree': 0.5808143570473069, 'gamma': 4.492770942635397, 'min_child_weight': 7, 'reg_alpha': 1.1846127780587211e-08, 'reg_lambda': 6.482945086231278e-08}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:58:00,479] Trial 23 finished with value: 0.48401244118587117 and parameters: {'n_estimators': 2159, 'max_depth': 3, 'learning_rate': 0.017279572377986996, 'subsample': 0.7743668946832931, 'colsample_bytree': 0.8459475988463466, 'gamma': 3.259806297513003, 'min_child_weight': 3, 'reg_alpha': 0.004982344702102993, 'reg_lambda': 7.906653376497142e-07}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:58:17,108] Trial 24 finished with value: 0.5028404192695527 and parameters: {'n_estimators': 1313, 'max_depth': 10, 'learning_rate': 0.09111430418810842, 'subsample': 0.924611705247089, 'colsample_bytree': 0.8288064461501716, 'gamma': 2.841543016677358, 'min_child_weight': 1, 'reg_alpha': 8.74432769454909e-06, 'reg_lambda': 1.323180041438319e-06}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:58:34,256] Trial 25 finished with value: 0.5016667399389283 and parameters: {'n_estimators': 1110, 'max_depth': 12, 'learning_rate': 0.038076147829554464, 'subsample': 0.9460232775885566, 'colsample_bytree': 0.8155693129986314, 'gamma': 3.974056517708242, 'min_child_weight': 6, 'reg_alpha': 0.00041231684401416913, 'reg_lambda': 8.712475112920381e-05}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:59:12,896] Trial 26 finished with value: 0.5129289649973428 and parameters: {'n_estimators': 988, 'max_depth': 10, 'learning_rate': 0.025985724173338116, 'subsample': 0.5121579832157269, 'colsample_bytree': 0.822736147953584, 'gamma': 0.8855533970352447, 'min_child_weight': 10, 'reg_alpha': 0.4279850668891566, 'reg_lambda': 0.2084083531336826}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 14:59:29,181] Trial 27 finished with value: 0.4909471341020223 and parameters: {'n_estimators': 1425, 'max_depth': 3, 'learning_rate': 0.23509266543399573, 'subsample': 0.7140920741586572, 'colsample_bytree': 0.9833274095218347, 'gamma': 4.818099885446264, 'min_child_weight': 9, 'reg_alpha': 2.2677289093956233e-06, 'reg_lambda': 1.2044307332953856e-05}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 15:00:10,672] Trial 28 finished with value: 0.49696635239569487 and parameters: {'n_estimators': 2628, 'max_depth': 6, 'learning_rate': 0.017797595772834223, 'subsample': 0.7784006312291751, 'colsample_bytree': 0.9680773870803905, 'gamma': 3.480148983374865, 'min_child_weight': 6, 'reg_alpha': 5.989794878601609e-08, 'reg_lambda': 0.0008318745034635068}. Best is trial 8 with value: 0.5250779765638034.
# [I 2025-12-29 15:00:42,971] Trial 29 finished with value: 0.4905902875090861 and parameters: {'n_estimators': 2976, 'max_depth': 4, 'learning_rate': 0.05829559595668967, 'subsample': 0.9386865359639778, 'colsample_bytree': 0.8703843088771022, 'gamma': 3.48507870497634, 'min_child_weight': 8, 'reg_alpha': 7.515003890531393e-06, 'reg_lambda': 2.2322084823690722e-06}. Best is trial 8 with value: 0.5250779765638034.
# ✅ NSGA-II Selesai dalam 910.39 detik.
# Best F1 NSGA-II: 0.5250779765638034

# %% [markdown]
# # Evaluasi Model Final & Komparasi

# %%
# Cell 8: Training Final & Komparasi Hasil (FIXED FOR XGBOOST 2.0)
def train_final_model(study, name):
    print(f"⚙️ Melatih Model Final: {name}...")
    params = study.best_params
    
    # Update parameter statis untuk XGBoost 2.0+
    params.update({
        'objective': 'multi:softmax',
        'num_class': len(le_target.classes_),
        'tree_method': 'hist',  # Ganti jadi 'hist'
        'device': 'cuda',       # Wajib 'cuda' untuk GPU
        'verbosity': 0
    })
    
    model = xgb.XGBClassifier(**params, random_state=42)
    model.fit(X_train_enc, y_train, sample_weight=sample_weights_train)
    
    preds = model.predict(X_test_enc)
    return model, preds

# 1. Train 3 Model
model_tpe, preds_tpe = train_final_model(study_tpe, "TPE")
model_asha, preds_asha = train_final_model(study_asha, "ASHA")
model_nsga, preds_nsga = train_final_model(study_nsga, "NSGA-II")

# 2. Hitung Metrik
def get_metrics(y_true, y_pred, time_taken, study):
    return {
        'Accuracy': accuracy_score(y_true, y_pred),
        'Precision (Macro)': precision_score(y_true, y_pred, average='macro'),
        'Recall (Macro)': recall_score(y_true, y_pred, average='macro'),
        'F1-Score (Macro)': f1_score(y_true, y_pred, average='macro'),
        'Waktu Optimasi (s)': time_taken,
        'Best Trial': study.best_trial.number,
        'Total Trials': len(study.trials)
    }

metrics_tpe = get_metrics(y_test, preds_tpe, time_tpe, study_tpe)
metrics_asha = get_metrics(y_test, preds_asha, time_asha, study_asha)
metrics_nsga = get_metrics(y_test, preds_nsga, time_nsga, study_nsga)

# 3. Tampilkan Tabel
df_compare = pd.DataFrame([metrics_tpe, metrics_asha, metrics_nsga], index=['TPE', 'ASHA', 'NSGA-II'])
print("\n=== HASIL AKHIR KOMPARASI ===")
display(df_compare)

# 4. Report
print("\n--- REPORT TPE ---")
print(classification_report(y_test, preds_tpe, target_names=le_target.classes_))
# Out:
# ⚙️ Melatih Model Final: TPE...
# ⚙️ Melatih Model Final: ASHA...
# ⚙️ Melatih Model Final: NSGA-II...
#
# === HASIL AKHIR KOMPARASI ===
#          Accuracy  Precision (Macro)  Recall (Macro)  F1-Score (Macro)  \
# TPE      0.717704           0.522151        0.593150          0.525542
# ASHA     0.701331           0.514468        0.598471          0.516765
# NSGA-II  0.703797           0.524790        0.610514          0.525078
#
#          Waktu Optimasi (s)  Best Trial  Total Trials
# TPE             1202.325456          28            30
# ASHA             255.790513           0            30
# NSGA-II          910.390092           8            30
# --- REPORT TPE ---
#                 precision    recall  f1-score   support
#
#       Analysis       0.03      0.09      0.05       677
#       Backdoor       0.03      0.23      0.05       583
#            DoS       0.29      0.25      0.27      4089
#       Exploits       0.78      0.65      0.71     11132
#        Fuzzers       0.27      0.59      0.37      6062
#        Generic       1.00      0.97      0.98     18871
#         Normal       0.97      0.69      0.80     37000
# Reconnaissance       0.89      0.83      0.86      3496
#      Shellcode       0.32      0.87      0.47       378
#          Worms       0.65      0.75      0.69        44
#
#       accuracy                           0.72     82332
#      macro avg       0.52      0.59      0.53     82332
#   weighted avg       0.84      0.72      0.76     82332

# %% [markdown]
# # Visualisasi (Confusion Matrix & Convergence)

# %%
# Cell 9: Visualisasi Lengkap

# --- A. Confusion Matrix (Side-by-Side 3 Metode) ---
def plot_cm(y_true, y_pred, title, ax):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, ax=ax,
                xticklabels=le_target.classes_, yticklabels=le_target.classes_)
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.set_xlabel('Prediksi')
    ax.tick_params(axis='x', rotation=45)

fig, axes = plt.subplots(1, 3, figsize=(24, 6))

plot_cm(y_test, preds_tpe, "CM - Metode TPE", axes[0])
plot_cm(y_test, preds_asha, "CM - Metode ASHA", axes[1])
plot_cm(y_test, preds_nsga, "CM - Metode NSGA-II", axes[2])

axes[0].set_ylabel('Label Asli (Aktual)')
plt.tight_layout()
plt.show()

# --- B. Plot Konvergensi Optimasi (History) ---
from optuna.visualization import plot_optimization_history

# TPE
print("\n=== 1. Riwayat Optimasi TPE ===")
plot_optimization_history(study_tpe)
plt.title("Optimization History - TPE")
plt.show() # Ini akan memunculkan pop-up window matplotlib standar

# ASHA
print("\n=== 2. Riwayat Optimasi ASHA ===")
plot_optimization_history(study_asha)
plt.title("Optimization History - ASHA")
plt.show()

# NSGA-II
print("\n=== 3. Riwayat Optimasi NSGA-II ===")
plot_optimization_history(study_nsga)
plt.title("Optimization History - NSGA-II")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_55/3313506356.py in <cell line: 0>()
#      10     ax.tick_params(axis='x', rotation=45)
#      11
# ---> 12 fig, axes = plt.subplots(1, 3, figsize=(24, 6))
#      13
#      14 plot_cm(y_test, preds_tpe, "CM - Metode TPE", axes[0])
#
# NameError: name 'plt' is not defined
